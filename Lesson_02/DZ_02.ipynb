# %% [markdown]
# ## Задание 1
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.
#
# ### Примеры работы программы:
#
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики’
# phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# Результат:
# Фраза 1 длиннее фразы 2
#
# phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики’
# Результат:
# Фраза 2 длиннее фразы 1
#
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики’
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики’
# Результат:
# Фразы равной длины

# %%
phrase_1 = "Насколько проще было бы писать программы, если бы не заказчики"
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else:
    print('Фразы равной длины')
# Out:
# Фраза 1 длиннее фразы 2

# %%
phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else:
    print('Фразы равной длины')
# Out:
# Фраза 2 длиннее фразы 1

# %%
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else:
    print('Фразы равной длины')
# Out:
# Фразы равной длины

# %% [markdown]
# ## Задание 2
# Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# ### Пример работы программы:
#
# year = 2020
# Результат:
# Високосный год
#
# year = 2019
# Результат:
# Обычный год

# %%
# Високосные года делятся нацело на 4. 
# Однако из этого правила есть исключение: столетия, которые не делятся нацело на 400, високосными не являются.
year = 2000
if (year % 4) != 0: # Если год не делится на 4, значит он обычный.
    print('Обычный год') 
elif (year % 100) != 0: # Иначе надо проверить не делится ли год на 100.
    print('Високосный год') # Если не делится, значит это не столетие и можно сделать вывод, что год високосный.
elif (year % 400) == 0: # Если делится на 100, значит это столетие и его следует проверить его делимость на 400.
    print('Високосный год') # Если год делится на 400, то он високосный.
else: # Иначе год обычный.
   print('Обычный год')
# Out:
# Високосный год

# %%
year = 2019
if (year % 4) != 0: # Если год не делится на 4, значит он обычный.
    print('Обычный год') 
elif (year % 100) != 0: # Иначе надо проверить не делится ли год на 100.
    print('Високосный год') # Если не делится, значит это не столетие и можно сделать вывод, что год високосный.
elif (year % 400) == 0: # Если делится на 100, значит это столетие и его следует проверить его делимость на 400.
    print('Високосный год') # Если год делится на 400, то он високосный.
else: # Иначе год обычный.
   print('Обычный год')
# Out:
# Обычный год

# %% [markdown]
# ## Задание 3
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# ### Пример работы программы:
#
# Введите день: 30
# Введите месяц: Август
# Результат:
# Ваш знак зодиака: Дева
#
# Введите день: 29
# Введите месяц: Октябрь
# Результат:
# Ваш знак зодиака: Скорпион

# %%
day = int(input('Введите день: '))
month = input('Введите месяц: ')
if (21<=day<=31 and month == 'март') or (1<=day<=20 and month == 'Апрель'): #21.03 - 20.04 - "Овен"
    print('Ваш знак зодиака: Овен')
elif (21<=day<=30 and month == 'Апрель') or (1<=day<=21 and month == 'Май'): #21.04 - 21.05 - "Телец"
    print('Ваш знак зодиака: Телец')
elif (22<=day<=31 and month == 'Май') or (1<=day<=21 and month == 'Июнь'): #22.05 - 21.06 - "Близнецы"
    print('Ваш знак зодиака: Близнецы')
elif (22<=day<=30 and month == 'Июнь') or (1<=day<=22 and month == 'Июль'): #22.06 - 22.07 - "Рак"
    print('Ваш знак зодиака: Рак')
elif (23<=day<=31 and month == 'Июль') or (1<=day<=23 and month == 'Август'): #23.07 - 23.08 - "Лев"
    print('Ваш знак зодиака: Лев')
elif (24<=day<=31 and month == 'Август') or (1<=day<=23 and month == 'Сентябрь'): #24.08 - 23.09 - "Дева"
    print('Ваш знак зодиака: Дева')
elif (24<=day<=30 and month == 'Сентябрь') or (1<=day<=23 and month == 'Октябрь'): #24.09 - 23.10 - "Весы"
    print('Ваш знак зодиака: Весы')
elif (24<=day<=31 and month == 'Октябрь') or (1<=day<=22 and month == 'Ноябрь'): #24.10 - 22.11 - "Скорпион"
    print('Ваш знак зодиака: Скорпион')
elif (23<=day<=30 and month == 'Ноябрь') or (1<=day<=21 and month == 'Декабрь'): #23.11 - 21.12 - "Стрелец"
    print('Ваш знак зодиака: Стрелец')
elif (22<=day<=31 and month == 'Декабрь') or (1<=day<=20 and month == 'Январь'): #22.12 - 20.01 - "Козерог"
    print('Ваш знак зодиака: Козерог')
elif (21<=day<=31 and month == 'Январь') or (1<=day<=19 and month == 'Февраль'): # 21.01 - 19.02 - "Водолей"
    print('Ваш знак зодиака: Водолей')
else:     # 20.02 - 20.03 - "Рыбы"
    print('Ваш знак зодиака: Рыбы')
# Out:
# Введите день: 30
# Введите месяц: Август
# Ваш знак зодиака: Дева

# %%
day = int(input('Введите день: '))
month = input('Введите месяц: ')
if (21<=day<=31 and month == 'март') or (1<=day<=20 and month == 'Апрель'): #21.03 - 20.04 - "Овен"
    print('Ваш знак зодиака: Овен')
elif (21<=day<=30 and month == 'Апрель') or (1<=day<=21 and month == 'Май'): #21.04 - 21.05 - "Телец"
    print('Ваш знак зодиака: Телец')
elif (22<=day<=31 and month == 'Май') or (1<=day<=21 and month == 'Июнь'): #22.05 - 21.06 - "Близнецы"
    print('Ваш знак зодиака: Близнецы')
elif (22<=day<=30 and month == 'Июнь') or (1<=day<=22 and month == 'Июль'): #22.06 - 22.07 - "Рак"
    print('Ваш знак зодиака: Рак')
elif (23<=day<=31 and month == 'Июль') or (1<=day<=23 and month == 'Август'): #23.07 - 23.08 - "Лев"
    print('Ваш знак зодиака: Лев')
elif (24<=day<=31 and month == 'Август') or (1<=day<=23 and month == 'Сентябрь'): #24.08 - 23.09 - "Дева"
    print('Ваш знак зодиака: Дева')
elif (24<=day<=30 and month == 'Сентябрь') or (1<=day<=23 and month == 'Октябрь'): #24.09 - 23.10 - "Весы"
    print('Ваш знак зодиака: Весы')
elif (24<=day<=31 and month == 'Октябрь') or (1<=day<=22 and month == 'Ноябрь'): #24.10 - 22.11 - "Скорпион"
    print('Ваш знак зодиака: Скорпион')
elif (23<=day<=30 and month == 'Ноябрь') or (1<=day<=21 and month == 'Декабрь'): #23.11 - 21.12 - "Стрелец"
    print('Ваш знак зодиака: Стрелец')
elif (22<=day<=31 and month == 'Декабрь') or (1<=day<=20 and month == 'Январь'): #22.12 - 20.01 - "Козерог"
    print('Ваш знак зодиака: Козерог')
elif (21<=day<=31 and month == 'Январь') or (1<=day<=19 and month == 'Февраль'): # 21.01 - 19.02 - "Водолей"
    print('Ваш знак зодиака: Водолей')
else:     # 20.02 - 20.03 - "Рыбы"
    print('Ваш знак зодиака: Рыбы')
# Out:
# Введите день: 29
# Введите месяц: Октябрь
# Ваш знак зодиака: Скорпион

# %% [markdown]
# ## Задание 4
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры хранятся в переменных (в сантиметрах):
#
# width = 10
# length = 205
# height = 5
#
# Используйте следующие правила:
#
# если каждое из трех измерений менее 15 сантиметров, то выведите на экран “Коробка №1”;
# если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите “Коробка №2”;
# если длина товара больше 2 метров, то выводите “Упаковка для лыж”;
# во всех остальных случаях выводите “Стандартная коробка №3”.

# %%
width = 10
length = 205
height = 5

if width<15 and length<15 and height<15:
    print('Коробка №1')
elif 15<width<50 or 15<length<50 or 15<height<50:
    print('Коробка №2')
elif length>200:
    print('Упаковка для лыж')
else:
    print('Стандартная коробка №3')
# Out:
# Упаковка для лыж

# %% [markdown]
# ## Задание 5 (необязательное)
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет “счастливым”. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# ### Примеры работы программы:
#
# number = 123456
# Результат:
# Несчастливый билет
#
# number = 123321
# Результат:
# Счастливый билет

# %%
number = 123456
n1 = round((number % 1000000)/1000000, 1)*10
n2 = round((number % 100000)/100000, 1)*10
n3 = round((number % 10000)/10000, 1)*10
n4 = round((number % 1000)/1000, 1)*10
n5 = round((number % 100)/100, 1)*10
n6 = round((number % 10)/10, 1)*10
sm1=n1+n2+n3
sm2=n4+n5+n6
if sm1 == sm2:
    print('Счастливый билет')
else:
    print('Несчастливый билет')
# Out:
# Несчастливый билет

# %%
number = 123321
n1 = number // 10**5 % 10
n2 = number // 10**4 % 10
n3 = number // 10**3 % 10
n4 = number // 10**2 % 10
n5 = number // 10**1 % 10
n6 = number // 10**0 % 10
sm1=n1+n2+n3
sm2=n4+n5+n6
if sm1 == sm2:
    print('Счастливый билет')
else:
    print('Несчастливый билет')
# Out:
# Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# если пользователь выбрал круг, запрашиваем его радиус,
# если треугольник – длины трех его сторон;
# если прямоугольник – длины двух его сторон.
#
# ### Пример работы программы:
#
# Введите тип фигуры:
# Круг
#
# Введите радиус круга:
# 10
#
# Результат:
# Площадь круга: 314.16
#
# Введите тип фигуры:
# Треугольник
#
# Введите длину стороны A:
# 2
#
# Введите длину стороны B:
# 2
#
# Введите длину стороны C:
# 3
#
# Результат:
# Площадь треугольника: 1.98

# %%
import math
F = int(input('Выберите одну из фигур: 1 - круг, 2 - треугольник, 3 - прямоугольник: '))
if F == 1:
    R = int(input('Введите радиус: '))
    S1 = math.pi * (R**2)
    print('Площадь круга: ', round(S1, 2))
elif F == 2:
    A = int(input('Введите длину стороны A: '))
    B = int(input('Введите длину стороны B: '))
    C = int(input('Введите длину стороны C: '))
    P = (A+B+C)/2
    S2 =  math.sqrt (P*(P - A) * (P - B) * (P - C))
    print('Площадь треугольника ', round(S2, 2))
elif F == 3:
    a = int(input('Введите ширинну '))
    b = int(input('Введите длину '))
    S3 = a * b
    print('Площадь прямоугольник ', round(S3, 2))
else:
    print('Вы не выбрали фигуру ')
# Out:
# Выберите одну из фигур: 1 - круг, 2 - треугольник, 3 - прямоугольник: 1
# Введите радиус: 10
# Площадь круга:  314.16
